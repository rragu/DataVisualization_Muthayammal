# %%
# !pip install summarytools
# Out:
# Collecting summarytools
#   Using cached summarytools-0.2.3-py3-none-any.whl
# Requirement already satisfied: matplotlib>=3.3.0 in c:\programdata\anaconda3\lib\site-packages (from summarytools) (3.4.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from summarytools) (1.26.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from summarytools) (2.1.3)
# Requirement already satisfied: ipython>=7.20.0 in c:\programdata\anaconda3\lib\site-packages (from summarytools) (7.29.0)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (67.8.0)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (3.0.20)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.1.2)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (5.1.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.4.4)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (2.17.2)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.18.0)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (9.5.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.3.0->summarytools) (1.16.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.4.0->summarytools) (2022.7)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckoff (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackoff (c:\programdata\anaconda3\lib\site-packages)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.4.0->summarytools) (2021.3)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.20.0->summarytools) (0.2.5)
# Installing collected packages: summarytools
# Successfully installed summarytools-0.2.3

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.3'

# %%
import pandas as pd
from summarytools import dfSummary

# %%
titanic = pd.read_csv('titanic.csv')
dfSummary(titanic, is_collapsible=True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-680" onclick = "coll_toggle_680()">Show Summary - titanic</button>
#     <div class="st-content" id="cont-680">
#       <style type="text/css">
# #T_37386 thead>tr>th {
#   text-align: left;
# }
# #T_37386_row0_col0, #T_37386_row1_col0, #T_37386_row2_col0, #T_37386_row3_col0, #T_37386_row4_col0, #T_37386_row5_col0, #T_37386_row6_col0, #T_37386_row7_col0, #T_37386_row8_col0, #T_37386_row9_col0, #T_37386_row10_col0, #T_37386_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_37386_row0_col1, #T_37386_row1_col1, #T_37386_row2_col1, #T_37386_row3_col1, #T_37386_row4_col1, #T_37386_row5_col1, #T_37386_row6_col1, #T_37386_row7_col1, #T_37386_row8_col1, #T_37386_row9_col1, #T_37386_row10_col1, #T_37386_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_37386_row0_col2, #T_37386_row1_col2, #T_37386_row2_col2, #T_37386_row3_col2, #T_37386_row4_col2, #T_37386_row5_col2, #T_37386_row6_col2, #T_37386_row7_col2, #T_37386_row8_col2, #T_37386_row9_col2, #T_37386_row10_col2, #T_37386_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_37386_row0_col3, #T_37386_row1_col3, #T_37386_row2_col3, #T_37386_row3_col3, #T_37386_row4_col3, #T_37386_row5_col3, #T_37386_row6_col3, #T_37386_row7_col3, #T_37386_row8_col3, #T_37386_row9_col3, #T_37386_row10_col3, #T_37386_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_37386_row0_col4, #T_37386_row1_col4, #T_37386_row2_col4, #T_37386_row3_col4, #T_37386_row4_col4, #T_37386_row5_col4, #T_37386_row6_col4, #T_37386_row7_col4, #T_37386_row8_col4, #T_37386_row9_col4, #T_37386_row10_col4, #T_37386_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_37386_row0_col5, #T_37386_row1_col5, #T_37386_row2_col5, #T_37386_row3_col5, #T_37386_row4_col5, #T_37386_row5_col5, #T_37386_row6_col5, #T_37386_row7_col5, #T_37386_row8_col5, #T_37386_row9_col5, #T_37386_row10_col5, #T_37386_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_37386">
#   <caption><strong>Data Frame Summary</strong><br>titanic<br>Dimensions: 891 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_37386_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_37386_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_37386_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_37386_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_37386_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_37386_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37386_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_37386_row0_col1" class="data row0 col1" ><strong>PassengerId</strong><br>[int64]</td>
#       <td id="T_37386_row0_col2" class="data row0 col2" >Mean (sd) : 446.0 (257.4)<br>min < med < max:<br>1.0 < 446.0 < 891.0<br>IQR (CV) : 445.0 (1.7)</td>
#       <td id="T_37386_row0_col3" class="data row0 col3" >891 distinct values</td>
#       <td id="T_37386_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_37386_row1_col1" class="data row1 col1" ><strong>Survived</strong><br>[int64]</td>
#       <td id="T_37386_row1_col2" class="data row1 col2" >Mean (sd) : 0.4 (0.5)<br>min < med < max:<br>0.0 < 0.0 < 1.0<br>IQR (CV) : 1.0 (0.8)</td>
#       <td id="T_37386_row1_col3" class="data row1 col3" >2 distinct values</td>
#       <td id="T_37386_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_37386_row2_col1" class="data row2 col1" ><strong>Pclass</strong><br>[int64]</td>
#       <td id="T_37386_row2_col2" class="data row2 col2" >Mean (sd) : 2.3 (0.8)<br>min < med < max:<br>1.0 < 3.0 < 3.0<br>IQR (CV) : 1.0 (2.8)</td>
#       <td id="T_37386_row2_col3" class="data row2 col3" >3 distinct values</td>
#       <td id="T_37386_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_37386_row3_col1" class="data row3 col1" ><strong>Name</strong><br>[object]</td>
#       <td id="T_37386_row3_col2" class="data row3 col2" >1. Braund, Mr. Owen Harris<br>2. Boulos, Mr. Hanna<br>3. Frolicher-Stehli, Mr. Maxmilli<br>4. Gilinski, Mr. Eliezer<br>5. Murdlin, Mr. Joseph<br>6. Rintamaki, Mr. Matti<br>7. Stephenson, Mrs. Walter Bertra<br>8. Elsbury, Mr. William James<br>9. Bourke, Miss. Mary<br>10. Chapman, Mr. John Henry<br>11. other</td>
#       <td id="T_37386_row3_col3" class="data row3 col3" >1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>1 (0.1%)<br>881 (98.9%)</td>
#       <td id="T_37386_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_37386_row4_col1" class="data row4 col1" ><strong>Sex</strong><br>[object]</td>
#       <td id="T_37386_row4_col2" class="data row4 col2" >1. male<br>2. female</td>
#       <td id="T_37386_row4_col3" class="data row4 col3" >577 (64.8%)<br>314 (35.2%)</td>
#       <td id="T_37386_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_37386_row5_col1" class="data row5 col1" ><strong>Age</strong><br>[float64]</td>
#       <td id="T_37386_row5_col2" class="data row5 col2" >Mean (sd) : 29.7 (14.5)<br>min < med < max:<br>0.4 < 28.0 < 80.0<br>IQR (CV) : 17.9 (2.0)</td>
#       <td id="T_37386_row5_col3" class="data row5 col3" >88 distinct values</td>
#       <td id="T_37386_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row5_col5" class="data row5 col5" >177<br>(19.9%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_37386_row6_col1" class="data row6 col1" ><strong>SibSp</strong><br>[int64]</td>
#       <td id="T_37386_row6_col2" class="data row6 col2" >Mean (sd) : 0.5 (1.1)<br>min < med < max:<br>0.0 < 0.0 < 8.0<br>IQR (CV) : 1.0 (0.5)</td>
#       <td id="T_37386_row6_col3" class="data row6 col3" >7 distinct values</td>
#       <td id="T_37386_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_37386_row7_col1" class="data row7 col1" ><strong>Parch</strong><br>[int64]</td>
#       <td id="T_37386_row7_col2" class="data row7 col2" >Mean (sd) : 0.4 (0.8)<br>min < med < max:<br>0.0 < 0.0 < 6.0<br>IQR (CV) : 0.0 (0.5)</td>
#       <td id="T_37386_row7_col3" class="data row7 col3" >7 distinct values</td>
#       <td id="T_37386_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_37386_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_37386_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_373

# %%
from summarytools import dfSummary, tabset

# %%
titanic = pd.read_csv('titanic.csv')
vaccine = pd.read_csv('country_vaccinations.csv')
vaccine['date'] = pd.to_datetime(vaccine['date'])

tabset({
    'titanic': dfSummary(titanic).render(),
    'vaccine': dfSummary(vaccine).render()})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8252/73095345.py in <module>
#       4
#       5 tabset({
# ----> 6     'titanic': dfSummary(titanic).render(),
#       7     'vaccine': dfSummary(vaccine).render()})
#
# AttributeError: 'Styler' object has no attribute 'render'
