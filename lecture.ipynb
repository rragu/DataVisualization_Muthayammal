# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Aadhirai\Downloads\Data Visualization\country_vaccinations.csv')

# %%
df
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  2021-01-10                 0.0                0.0
# 1     Albania      ALB  2021-01-11                 NaN                NaN
# 2     Albania      ALB  2021-01-12               128.0              128.0
# 3     Albania      ALB  2021-01-13               188.0              188.0
# 4     Albania      ALB  2021-01-14               266.0              266.0
# ...       ...      ...         ...                 ...                ...
# 2911    Wales      NaN  2021-02-06            592228.0           589622.0
# 2912    Wales      NaN  2021-02-07            606768.0           603976.0
# 2913    Wales      NaN  2021-02-08            632251.0           628760.0
# 2914    Wales      NaN  2021-02-09            659106.0           655419.0
# 2915    Wales      NaN  2021-02-10            687892.0           684097.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916 entries, 0 to 2915
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              2916 non-null   object
#  1   iso_code                             2676 non-null   object
#  2   date                                 2916 non-null   object
#  3   total_vaccinations                   1868 non-null   float64
#  4   people_vaccinated                    1530 non-null   float64
#  5   people_fully_vaccinated              938 non-null    float64
#  6   daily_vaccinations_raw               1539 non-null   float64
#  7   daily_vaccinations                   2801 non-null   float64
#  8   total_vaccinations_per_hundred       1868 non-null   float64
#  9   people_vaccinated_per_hundred        1530 non-null   float64
#  10  people_fully_vaccinated_per_hundred  938 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                                       count          mean           std  min  \
# total_vaccinations                   1868.0  1.252920e+06  4.149778e+06  0.0
# people_vaccinated                    1530.0  1.058740e+06  3.461625e+06  0.0
# people_fully_vaccinated               938.0  2.965334e+05  1.042177e+06  1.0
# daily_vaccinations_raw               1539.0  6.951993e+04  1.930803e+05  0.0
# daily_vaccinations                   2801.0  5.555575e+04  1.720739e+05  1.0
# total_vaccinations_per_hundred       1868.0  4.967505e+00  9.487874e+00  0.0
# people_vaccinated_per_hundred        1530.0  4.449157e+00  7.545322e+00  0.0
# people_fully_vaccinated_per_hundred   938.0  1.281109e+00  3.488210e+00  0.0
# daily_vaccinations_per_million       2801.0  2.024456e+03  3.562163e+03  0.0
#
#                                           25%         50%          75%  \
# total_vaccinations                   25492.50  153830.000  653250.2500
# ...

# %%
df.columns.to_list()
# Out:
# ['country',
#  'iso_code',
#  'date',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'daily_vaccinations_raw',
#  'daily_vaccinations',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'daily_vaccinations_per_million',
#  'vaccines',
#  'source_name',
#  'source_website']

# %%
df
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  2021-01-10                 0.0                0.0
# 1     Albania      ALB  2021-01-11                 NaN                NaN
# 2     Albania      ALB  2021-01-12               128.0              128.0
# 3     Albania      ALB  2021-01-13               188.0              188.0
# 4     Albania      ALB  2021-01-14               266.0              266.0
# ...       ...      ...         ...                 ...                ...
# 2911    Wales      NaN  2021-02-06            592228.0           589622.0
# 2912    Wales      NaN  2021-02-07            606768.0           603976.0
# 2913    Wales      NaN  2021-02-08            632251.0           628760.0
# 2914    Wales      NaN  2021-02-09            659106.0           655419.0
# 2915    Wales      NaN  2021-02-10            687892.0           684097.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
df.rename(columns={'country':'COUNTRY'}, inplace=True)

# %%
df.head(10)
# Out:
#    COUNTRY iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
# 5  Albania      ALB  2021-01-15               308.0              308.0
# 6  Albania      ALB  2021-01-16               369.0              369.0
# 7  Albania      ALB  2021-01-17               405.0              405.0
# 8  Albania      ALB  2021-01-18               447.0              447.0
# 9  Albania      ALB  2021-01-19               483.0              483.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
df["COUNTRY"].value_counts()
# Out:
# COUNTRY
# Wales               60
# United Kingdom      60
# Scotland            60
# England             60
# Northern Ireland    60
#                     ..
# Iran                 2
# Algeria              2
# Saint Helena         1
# Greenland            1
# Liechtenstein        1
# Name: count, Length: 85, dtype: int64

# %%
df[].fillna(0)
# Out:
#       COUNTRY iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  2021-01-10                 0.0                0.0
# 1     Albania      ALB  2021-01-11                 0.0                0.0
# 2     Albania      ALB  2021-01-12               128.0              128.0
# 3     Albania      ALB  2021-01-13               188.0              188.0
# 4     Albania      ALB  2021-01-14               266.0              266.0
# ...       ...      ...         ...                 ...                ...
# 2911    Wales        0  2021-02-06            592228.0           589622.0
# 2912    Wales        0  2021-02-07            606768.0           603976.0
# 2913    Wales        0  2021-02-08            632251.0           628760.0
# 2914    Wales        0  2021-02-09            659106.0           655419.0
# 2915    Wales        0  2021-02-10            687892.0           684097.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...
