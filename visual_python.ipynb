# %%
# !pip install visualpython
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)

# %%
# !visualpy install
# Out:
# Package install command: pip
# ...
# Copy visualpython extension files ...
# ------------------------------------------------------------------------------------------
# Source Dir : c:\programdata\anaconda3\lib\site-packages\visualpython
# Target Dir : C:\ProgramData\Anaconda3\share\jupyter\nbextensions\visualpython
# ...
# 549 File(s) copied
# Enabling notebook extension visualpython/visualpython...
#       - Validating: ok

# %%
# !pip install jupyterlab-visualpython
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('employee_dataset.csv')
df
# Out:
#                  Name                Company_Name  \
# 0      Johnny Maynard     White, Mcclain and Cobb
# 1    Michael Williams                   Scott Inc
# 2         Laura Flynn                 Andrade LLC
# 3     Stefanie Archer              James and Sons
# 4       Sierra Garcia                Matthews Inc
# ..                ...                         ...
# 995       Mark Gordon    Baker, Allen and Edwards
# 996     Courtney Bell                 Andrade LLC
# 997     Kathleen Lamb  Wallace, Smith and Shepard
# 998       Renee Davis               Nichols-James
# 999  Lindsey Sullivan    Baker, Allen and Edwards
#
#                                     Employee_Job_Title      Employee_City  \
# 0                                      Equities trader   New Cindychester
# 1                                      Patent examiner       Ricardomouth
# 2                                      Equities trader  North Melissafurt
# ...

# %%
# Visual Python: Data Analysis > Groupby
df.groupby(['Employee_Country','Employment_Status'])['Employee_Rating'].max()
# Out:
# Employee_Country  Employment_Status
# Afghanistan       Full Time            1.2
#                   Intern               0.7
# Albania           Full Time            4.7
# Algeria           Full Time            3.5
# American Samoa    Full Time            4.3
#                                       ...
# Western Sahara    Intern               4.4
# Yemen             Full Time            4.5
#                   Intern               0.8
# Zambia            Full Time            4.9
# Zimbabwe          Full Time            4.4
# Name: Employee_Rating, Length: 376, dtype: float64

# %%
# Visual Python: Visualization > Plotly
import plotly.express as px
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Visual Python: Visualization > Plotly
fig = px.scatter(df, x='Employee_Country', y='Employee_Salary')
fig.update_xaxes(categoryorder='total ascending')
fig.show()
# Out:
# <div>                            <div id="3680380f-4bf6-4b3a-a7a7-ff409a9677cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3680380f-4bf6-4b3a-a7a7-ff409a9677cd")) {                    Plotly.newPlot(                        "3680380f-4bf6-4b3a-a7a7-ff409a9677cd",                        [{"hovertemplate":"Employee_Country=%{x}<br>Employee_Salary=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Mongolia","Guinea-Bissau","Tonga","San Marino","Nepal","Tonga","Portugal","Libyan Arab Jamahiriya","Kyrgyz Republic","Haiti","Korea","Comoros","Georgia","Panama","Uruguay","Brunei Darussalam","Namibia","Mexico","Greenland","Iceland","Kyrgyz Republic","P
# ...

# %%
# Visual Python: Logic > code
import plotly.express as px
import plotly
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Visual Python: Visualization > Plotly
fig = px.scatter(df, x='Employee_Rating', y='Company_Name')
fig.update_xaxes(categoryorder='total descending')
fig.show()
# Out:
# <div>                            <div id="b3333d3a-5759-4d58-a728-e3dec9ab49d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3333d3a-5759-4d58-a728-e3dec9ab49d2")) {                    Plotly.newPlot(                        "b3333d3a-5759-4d58-a728-e3dec9ab49d2",                        [{"hovertemplate":"Employee_Rating=%{x}<br>Company_Name=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[3.3,4.6,0.3,2.8,4.5,1.1,4.7,3.4,3.7,3.0,3.4,0.3,2.9,4.8,1.7,2.0,1.6,0.4,3.5,1.7,1.9,1.9,2.8,4.5,1.3,1.3,2.1,2.0,0.0,3.9,2.0,0.5,1.2,3.7,1.0,3.0,4.4,2.3,3.1,0.6,5.0,4.5,3.6,0.1,4.5,2.6,3.3,4.1,0.9,1.0,2.1,4.2,0.5,1.0,4.6,2.7,1.7,1.6,4.7,3.8,1.1,1.6,0.1,1.9,2.
# ...
